# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Author
# Mahmoud Taha Abdelaal

# %% [markdown]
# In this notebook, I will be summarizing the tools for data science and jupyter notebook ecosystem

# %% [markdown]
# Objectives of this notebook:
# - Being able to name at least three popular data science languages
# - Being able to list three of the most important data science libraries
# - A brief introduction to markdown including (lists, tables, headings)
# - To be able to evaluate basic arithmetic operations using Python
# - Program a simple algorithm that converts minutes to hours

# %% [markdown]
# Some popular data science tools include -but not limited to-:
# 1. Julia
# 2. Python
# 3. R

# %% [markdown]
# Commonly used data science libraries include:
# 1. MatPlotLib
# 2. Pandas
# 3. ggplot

# %% [markdown]
# | Data Science Tools  |
# |---------------------|
# | VS Code             |
# | JupyterLab          |
# | Google Colaboratory |
# | JupyterLab          |

# %% [markdown]
# ### Here are a few examples of evaluating arithmetic expressions in Python

# %%
# the below expression demonstrates the presedence of operations in Python

(3 * 4) + 5
# Out:
# 17

# %%
# the below code function converts minutes to hours 
def f(x):
    return x / 60 

# passing 200 -minutes- to the function we get the following result
f(200)
# Out:
# 3.3333333333333335
